# %% [markdown]
# # **Team Playbook: Agentic Scaffold for Projects**

# %% [markdown]
# # Team Playbook Repo
#
# This repository is a self-contained team playbook and working Python scaffold for running AI development projects with:
#
# - `AGENTS.md` for team and agent operating rules
# - `CLAUDE.md` for implementation discipline and guardrails
# - `SKILLS.md` for reusable capabilities
# - workflow definitions for planning, building, reviewing, and releasing
# - a lightweight orchestrator that runs agents against a task
# - local mock MCP-style tools so the system works without external services
#
# ## What this repo is
#
# This repo is designed to help a new AI development team:
#
# 1. understand how responsibilities are divided,
# 2. follow a repeatable operating model,
# 3. run a small end-to-end workflow locally,
# 4. extend the system as the project grows.
#
# ## Repository layout
#
# ```text
# team_playbook_repo/
# ├── AGENTS.md
# ├── CLAUDE.md
# ├── SKILLS.md
# ├── README.md
# ├── pyproject.toml
# ├── config/
# │   ├── agents.json
# │   ├── skills.json
# │   └── workflows.json
# ├── docs/
# │   └── TEAM_WORKFLOWS.md
# ├── scripts/
# │   └── run_demo.py
# └── src/
#     └── team_playbook/
#         ├── __init__.py
#         ├── agents.py
#         ├── cli.py
#         ├── mcp.py
#         ├── models.py
#         ├── orchestrator.py
#         └── registry.py
# ```
# The demo loads the defined agents, skills, and workflows from the config files, then runs a task through this sequence:
#
# 1. IntakeAgent
# 2. PlannerAgent
# 3. BuilderAgent
# 4. ReviewerAgent
# 5. ReleaseAgent
#
# Each agent uses local mock MCP-style tools to:
#
# - log actions,
# - read/write notes,
# - produce a simple structured result.
#
# This is intentionally lightweight so the repo runs out of the box.
#
# ## How to adapt it
#
# - Update `AGENTS.md` when team roles or responsibilities change.
# - Update `CLAUDE.md` when implementation rules or review discipline need to change.
# - Update `SKILLS.md` when the team adds reusable capabilities.
# - Update `config/workflows.json` to add project-specific delivery flows.
# - Replace mock MCP tools in `src/team_playbook/mcp.py` with real service integrations when ready.
#
# ## Recommended team usage
#
# Use this repo in three layers:
#
# ### Layer 1: Governance
#
# - `AGENTS.md`
# - `CLAUDE.md`
# - `SKILLS.md`
#
# These define how the team works.
#
# ### Layer 2: Execution
#
# - workflow definitions
# - orchestrator
# - agents
# - skills
#
# These define how tasks move through the system.
#
# ### Layer 3: Tooling
#
# - local MCP-style tools
# - future real integrations
#
# These define how the system acts on the environment.
#
# ## Success criteria for a team using this repo
#
# A task is considered well-executed when:
#
# - the correct workflow is selected,
# - each agent performs its defined role,
# - outputs are handed off in a predictable structure,
# - review happens before release,
# - release artifacts summarize what was built and why.
#
# ## Next extension ideas
#
# - add persistent storage,
# - add real tool integrations,
# - add test execution and gating,
# - add richer prompt templates,
# - add role-based workflow variants,
# - add CI checks to verify config consistency.

# %% [markdown]
# ## 1. Clone Repository

# %%
# !git clone https://github.com/dshipley71/team_playbook.git
# Out:
# Cloning into 'team_playbook'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 24 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (24/24), 13.31 KiB | 6.66 MiB/s, done.

# %% [markdown]
# ## 2. Install Project

# %%
# %cd team_playbook
# Out:
# /content/team_playbook

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/team_playbook
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Building wheels for collected packages: team-playbook-repo
#   Building editable for team-playbook-repo (pyproject.toml) ... done
#   Created wheel for team-playbook-repo: filename=team_playbook_repo-0.1.0-0.editable-py3-none-any.whl size=2934 sha256=163b4ed45da8ad0b0908e1c616e8b22c9b85f6291fd704e616a43bef8cccb8cd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nk5fl_mi/wheels/8a/1f/8a/388dba9bcedde0c1e7979e7b3f0ca433202cddbfa9e4f26fea
# Successfully built team-playbook-repo
# Installing collected packages: team-playbook-repo
# Successfully installed team-playbook-repo-0.1.0

# %% [markdown]
# ## 3. Run Scaffolding Demo test #1

# %%
# !python scripts/run_demo.py
# Out:
# {
#   "workflow": {
#     "name": "feature_delivery",
#     "description": "Standard feature delivery with review and release packaging.",
#     "sequence": [
#       "IntakeAgent",
#       "PlannerAgent",
#       "BuilderAgent",
#       "ReviewerAgent",
#       "ReleaseAgent"
#     ]
#   },
#   "results": [
#     {
#       "agent_name": "IntakeAgent",
#       "summary": "Structured incoming request into a standard handoff package.",
#       "handoff": {
#         "task": "Create a new internal team playbook workflow and release summary",
#         "objective": "Deliver requested outcome for task: Create a new internal team playbook workflow and release summary",
#         "constraints": [
#           "Keep outputs aligned with repository rules."
#         ],
#         "decisions": [
#           "Use structured five-stage workflow."
#         ],
#         "artifacts": [
#           "intake_summary"
#         ],
#         "risks": [
#           "Original request may omit hidden assumptions."
#         ],
#         "next_action": "Create a concrete implementation plan.",
#         "notes": {
#           "intake": "Structured request for: Create a new internal team playbook workflow and release summary"
#         }
#       }
#     },
#     {
#       "agent_name": "PlannerAgent",
#       "summary": "Created an ordered implementation plan.",
#       "handoff": {
#         "task": "Create a new internal team playbook workflow and release summary",
#         "objective": "Deliver requested outcome for task: Create a new internal team playbook workflow and release summary",
#         "constraints": [
#           "Keep outputs aligned with repository rules.",
#           "Follow ordered workflow steps."
#         ],
#         "decisions": [
#           "Use structured five-stage workflow.",
#           "Plan steps: clarify scope, identify affected files, implement changes, review quality, package release"
#         ],
#         "artifacts": [
#           "intake_summary",
#           "implementation_plan"
#         ],
#         "risks": [
#           "Original request may omit hidden assumptions.",
#           "Implementation may drift if the plan is ignored."
#         ],
#         "next_action": "Execute the implementation plan.",
#         "notes": {
#           "intake": "Structured request for: Create a new internal team playbook workflow and release summary",
#           "plan": "clarify scope -> identify affected files -> implement changes -> review quality -> package release"
#         }
#       }
#     },
#     {
#       "agent_name": "BuilderAgent",
#       "summary": "Produced a scoped implementation summary.",
#       "handoff": {
#         "task": "Create a new internal team playbook workflow and release summary",
#         "objective": "Deliver requested outcome for task: Create a new internal team playbook workflow and release summary",
#         "constraints": [
#           "Keep outputs aligned with repository rules.",
#           "Follow ordered workflow steps."
#         ],
#         "decisions": [
#           "Use structured five-stage workflow.",
#           "Plan steps: clarify scope, identify affected files, implement changes, review quality, package release",
#           "Kept implementation scoped to plan."
#         ],
#         "artifacts": [
#           "intake_summary",
#           "implementation_plan",
#           "build_output"
#         ],
#         "risks": [
#           "Original request may omit hidden assumptions.",
#           "Implementation may drift if the plan is ignored."
#         ],
#         "next_action": "Review the produced artifacts for correctness and readiness.",
#         "notes": {
#           "intake": "Structured request for: Create a new internal team playbook workflow and release summary",
#           "plan": "clarify scope -> identify affected files -> implement changes -> review quality -> package release",
#           "build": "Implemented task 'Create a new internal team playbook workflow and release summary' using plan: clarify scope -> identify affected files -> implement changes -> review quality -> package release"
#         }
#       }
#     },
#     {
#       "agent_name": "ReviewerAgent",
#       "summary": "Completed review with status: approved.",
#       "handoff": {
#         "task": "Create a new internal team playbook workflow and release summary",
#         "objective": "Deliver requested outcome for task: Create a new internal team playbook workflow and release summary",
#         "constraints": [
#           "Keep outputs aligned with repository rules.",
#           "Follow ordered workflow steps."
#         ],
#         "decisions": [
#           "Use structured five-stage workflow.",
#           "Plan steps: clarify scope, identify affected files, implement changes, review quality, package release",
#           "Kept implementation scoped to plan.",
#           "Review status: approved"
#         ],
#         "artifacts": [
#           "intake_summary",
#           "implementation_plan",
#           "build_output",
#           "review_report"
#         ],
#         "risks": [
#           "Original request may omit hidden assumptions.",
#           "Implementation may drift if the plan is ignored."
#         ],
#         "next_action": "Package release notes and final handoff.",
#         "notes": {
#           "intake": "Structured request for: Create a new internal team playbook workflow and release summary",
#           "plan": "clarify scope -> identify affected files -> implement changes -> review quality -> package release",
#           "build": "Implemented task 'Create a new internal team playbook workflow and release summary' using plan: clarify scope -> identify affected files -> implement changes -> review quality -> package release",
#           "review": "Artifacts are aligned with plan and ready for release.",
#           "review_status": "approved"
#         }
#       }
#     },
#     {
#       "agent_name": "ReleaseAgent",
#       "summary": "Prepared release notes and final handoff.",
#       "handoff": {
#         "task": "Create a new internal team playbook workflow and release summary",
#         "objective": "Deliver requested outcome for task: Create a new internal team playbook workflow and release summary",
#         "constraints": [
#           "Keep outputs aligned with repository rules.",
#           "Follow ordered workflow steps."
#         ],
#         "decisions": [
#           "Use structured five-stage workflow.",
#           "Plan steps: clarify scope, identify affected files, implement changes, review quality, package release",
#           "Kept implementation scoped to plan.",
#           "Review status: approved",
#           "Prepared final release package."
#         ],
#         "artifacts": [
#           "intake_summary",
#           "implementation_plan",
#           "build_output",
#           "review_report",
#           "release_notes"
#         ],
#         "risks": [
#           "Original request may omit hidden assumptions.",
#           "Implementation may drift if the plan is ignored."
#         ],
#         "next_action": "Share final handoff with downstream team.",
#         "notes": {
#           "intake": "Structured request for: Create a new internal team playbook workflow and release summary",
#           "plan": "clarify scope -> identify affected files -> implement changes -> review quality -> package release",
#           "build": "Implemented task 'Create a new internal team playbook workflow and release summary' using plan: clarify scope -> identify affected files -> implement changes -> review quality -> package release",
#           "review": "Artifacts are aligned with plan and ready for release.",
#           "review_status": "approved",
#           "release": "Released task 'Create a new internal team playbook workflow and release summary'. Summary: Implemented task 'Create a new internal team playbook workflow and release summary' using plan: clarify scope -> identify affected files -> implement changes -> review quality -> package release"
#         }
#       }
#     }
#   ],
#   "tool_snapshot": {
#     "notes": {
#       "intake_summary": "Structured request for: Create a new internal team playbook workflow and release summary",
#       "implementation_plan": "clarify scope -> identify affected files -> implement changes -> review quality -> package release",
#       "build_output": "Implemented task 'Create a new internal team playbook workflow and release summary' using plan: clarify scope -> identify affected files -> implement changes -> review quality -> package release",
#       "review_report": "Artifacts are aligned with plan and ready for release.",
#       "release_notes": "Released task 'Create a new internal team playbook workflow and release summary'. Summary: Implemented task 'Create a new internal team playbook workflow and release summary' using plan: clarify scope -> identify affected files -> implement changes -> review quality -> package release"
#     },
#     "log_entries": [
#       "[2026-03-30T16:23:09Z] IntakeAgent started",
#       "[2026-03-30T16:23:09Z] note_written key=intake_summary",
#       "[2026-03-30T16:23:09Z] PlannerAgent started",
#       "[2026-03-30T16:23:09Z] note_written key=implementation_plan",
#       "[2026-03-30T16:23:09Z] BuilderAgent started",
#       "[2026-03-30T16:23:09Z] note_written key=build_output",
#       "[2026-03-30T16:23:09Z] ReviewerAgent started",
#       "[2026-03-30T16:23:09Z] note_written key=review_report",
#       "[2026-03-30T16:23:09Z] ReleaseAgent started",
#       "[2026-03-30T16:23:09Z] note_written key=release_notes"
#     ]
#   },
#   "final_handoff": {
#     "task": "Create a new internal team playbook workflow and release summary",
#     "objective": "Deliver requested outcome for task: Create a new internal team playbook workflow and release summary",
#     "constraints": [
#       "Keep outputs aligned with repository rules.",
#       "Follow ordered workflow steps."
#     ],
#     "decisions": [
#       "Use structured five-stage workflow.",
#       "Plan steps: clarify scope, identify affected files, implement changes, review quality, package release",
#       "Kept implementation scoped to plan.",
#       "Review status: approved",
#       "Prepared final release package."
#     ],
#     "artifacts": [
#       "intake_summary",
#       "implementation_plan",
#       "build_output",
#       "review_report",
#       "release_notes"
#     ],
#     "risks": [
#       "Original request may omit hidden assumptions.",
#       "Implementation may drift if the plan is ignored."
#     ],
#     "next_action": "Share final handoff with downstream team.",
#     "notes": {
#       "intake": "Structured request for: Create a new internal team playbook workflow and release summary",
#       "plan": "clarify scope -> identify affected files -> implement changes -> review quality -> package release",
#       "build": "Implemented task 'Create a new internal team playbook workflow and release summary' using plan: clarify scope -> identify affected files -> implement changes -> review quality -> package release",
#       "review": "Artifacts are aligned with plan and ready for release.",
#       "review_status": "approved",
#       "release": "Released task 'Create a new internal team playbook workflow and release summary'. Summary: Implemented task 'Create a new internal team playbook workflow and release summary' using plan: clarify scope -> identify affected files -> implement changes -> review quality -> package release"
#     }
#   }
# }

# %% [markdown]
# ## 4. Run Scaffolding Demo Test #2

# %%
# !python -m team_playbook.cli --workflow feature_delivery --task "Build a document ingestion feature with validation and release notes"
# Out:
# {
#   "workflow": {
#     "name": "feature_delivery",
#     "description": "Standard feature delivery with review and release packaging.",
#     "sequence": [
#       "IntakeAgent",
#       "PlannerAgent",
#       "BuilderAgent",
#       "ReviewerAgent",
#       "ReleaseAgent"
#     ]
#   },
#   "results": [
#     {
#       "agent_name": "IntakeAgent",
#       "summary": "Structured incoming request into a standard handoff package.",
#       "handoff": {
#         "task": "Build a document ingestion feature with validation and release notes",
#         "objective": "Deliver requested outcome for task: Build a document ingestion feature with validation and release notes",
#         "constraints": [
#           "Keep outputs aligned with repository rules."
#         ],
#         "decisions": [
#           "Use structured five-stage workflow."
#         ],
#         "artifacts": [
#           "intake_summary"
#         ],
#         "risks": [
#           "Original request may omit hidden assumptions."
#         ],
#         "next_action": "Create a concrete implementation plan.",
#         "notes": {
#           "intake": "Structured request for: Build a document ingestion feature with validation and release notes"
#         }
#       }
#     },
#     {
#       "agent_name": "PlannerAgent",
#       "summary": "Created an ordered implementation plan.",
#       "handoff": {
#         "task": "Build a document ingestion feature with validation and release notes",
#         "objective": "Deliver requested outcome for task: Build a document ingestion feature with validation and release notes",
#         "constraints": [
#           "Keep outputs aligned with repository rules.",
#           "Follow ordered workflow steps."
#         ],
#         "decisions": [
#           "Use structured five-stage workflow.",
#           "Plan steps: clarify scope, identify affected files, implement changes, review quality, package release"
#         ],
#         "artifacts": [
#           "intake_summary",
#           "implementation_plan"
#         ],
#         "risks": [
#           "Original request may omit hidden assumptions.",
#           "Implementation may drift if the plan is ignored."
#         ],
#         "next_action": "Execute the implementation plan.",
#         "notes": {
#           "intake": "Structured request for: Build a document ingestion feature with validation and release notes",
#           "plan": "clarify scope -> identify affected files -> implement changes -> review quality -> package release"
#         }
#       }
#     },
#     {
#       "agent_name": "BuilderAgent",
#       "summary": "Produced a scoped implementation summary.",
#       "handoff": {
#         "task": "Build a document ingestion feature with validation and release notes",
#         "objective": "Deliver requested outcome for task: Build a document ingestion feature with validation and release notes",
#         "constraints": [
#           "Keep outputs aligned with repository rules.",
#           "Follow ordered workflow steps."
#         ],
#         "decisions": [
#           "Use structured five-stage workflow.",
#           "Plan steps: clarify scope, identify affected files, implement changes, review quality, package release",
#           "Kept implementation scoped to plan."
#         ],
#         "artifacts": [
#           "intake_summary",
#           "implementation_plan",
#           "build_output"
#         ],
#         "risks": [
#           "Original request may omit hidden assumptions.",
#           "Implementation may drift if the plan is ignored."
#         ],
#         "next_action": "Review the produced artifacts for correctness and readiness.",
#         "notes": {
#           "intake": "Structured request for: Build a document ingestion feature with validation and release notes",
#           "plan": "clarify scope -> identify affected files -> implement changes -> review quality -> package release",
#           "build": "Implemented task 'Build a document ingestion feature with validation and release notes' using plan: clarify scope -> identify affected files -> implement changes -> review quality -> package release"
#         }
#       }
#     },
#     {
#       "agent_name": "ReviewerAgent",
#       "summary": "Completed review with status: approved.",
#       "handoff": {
#         "task": "Build a document ingestion feature with validation and release notes",
#         "objective": "Deliver requested outcome for task: Build a document ingestion feature with validation and release notes",
#         "constraints": [
#           "Keep outputs aligned with repository rules.",
#           "Follow ordered workflow steps."
#         ],
#         "decisions": [
#           "Use structured five-stage workflow.",
#           "Plan steps: clarify scope, identify affected files, implement changes, review quality, package release",
#           "Kept implementation scoped to plan.",
#           "Review status: approved"
#         ],
#         "artifacts": [
#           "intake_summary",
#           "implementation_plan",
#           "build_output",
#           "review_report"
#         ],
#         "risks": [
#           "Original request may omit hidden assumptions.",
#           "Implementation may drift if the plan is ignored."
#         ],
#         "next_action": "Package release notes and final handoff.",
#         "notes": {
#           "intake": "Structured request for: Build a document ingestion feature with validation and release notes",
#           "plan": "clarify scope -> identify affected files -> implement changes -> review quality -> package release",
#           "build": "Implemented task 'Build a document ingestion feature with validation and release notes' using plan: clarify scope -> identify affected files -> implement changes -> review quality -> package release",
#           "review": "Artifacts are aligned with plan and ready for release.",
#           "review_status": "approved"
#         }
#       }
#     },
#     {
#       "agent_name": "ReleaseAgent",
#       "summary": "Prepared release notes and final handoff.",
#       "handoff": {
#         "task": "Build a document ingestion feature with validation and release notes",
#         "objective": "Deliver requested outcome for task: Build a document ingestion feature with validation and release notes",
#         "constraints": [
#           "Keep outputs aligned with repository rules.",
#           "Follow ordered workflow steps."
#         ],
#         "decisions": [
#           "Use structured five-stage workflow.",
#           "Plan steps: clarify scope, identify affected files, implement changes, review quality, package release",
#           "Kept implementation scoped to plan.",
#           "Review status: approved",
#           "Prepared final release package."
#         ],
#         "artifacts": [
#           "intake_summary",
#           "implementation_plan",
#           "build_output",
#           "review_report",
#           "release_notes"
#         ],
#         "risks": [
#           "Original request may omit hidden assumptions.",
#           "Implementation may drift if the plan is ignored."
#         ],
#         "next_action": "Share final handoff with downstream team.",
#         "notes": {
#           "intake": "Structured request for: Build a document ingestion feature with validation and release notes",
#           "plan": "clarify scope -> identify affected files -> implement changes -> review quality -> package release",
#           "build": "Implemented task 'Build a document ingestion feature with validation and release notes' using plan: clarify scope -> identify affected files -> implement changes -> review quality -> package release",
#           "review": "Artifacts are aligned with plan and ready for release.",
#           "review_status": "approved",
#           "release": "Released task 'Build a document ingestion feature with validation and release notes'. Summary: Implemented task 'Build a document ingestion feature with validation and release notes' using plan: clarify scope -> identify affected files -> implement changes -> review quality -> package release"
#         }
#       }
#     }
#   ],
#   "tool_snapshot": {
#     "notes": {
#       "intake_summary": "Structured request for: Build a document ingestion feature with validation and release notes",
#       "implementation_plan": "clarify scope -> identify affected files -> implement changes -> review quality -> package release",
#       "build_output": "Implemented task 'Build a document ingestion feature with validation and release notes' using plan: clarify scope -> identify affected files -> implement changes -> review quality -> package release",
#       "review_report": "Artifacts are aligned with plan and ready for release.",
#       "release_notes": "Released task 'Build a document ingestion feature with validation and release notes'. Summary: Implemented task 'Build a document ingestion feature with validation and release notes' using plan: clarify scope -> identify affected files -> implement changes -> review quality -> package release"
#     },
#     "log_entries": [
#       "[2026-03-30T16:24:28Z] IntakeAgent started",
#       "[2026-03-30T16:24:28Z] note_written key=intake_summary",
#       "[2026-03-30T16:24:28Z] PlannerAgent started",
#       "[2026-03-30T16:24:28Z] note_written key=implementation_plan",
#       "[2026-03-30T16:24:28Z] BuilderAgent started",
#       "[2026-03-30T16:24:28Z] note_written key=build_output",
#       "[2026-03-30T16:24:28Z] ReviewerAgent started",
#       "[2026-03-30T16:24:28Z] note_written key=review_report",
#       "[2026-03-30T16:24:28Z] ReleaseAgent started",
#       "[2026-03-30T16:24:28Z] note_written key=release_notes"
#     ]
#   },
#   "final_handoff": {
#     "task": "Build a document ingestion feature with validation and release notes",
#     "objective": "Deliver requested outcome for task: Build a document ingestion feature with validation and release notes",
#     "constraints": [
#       "Keep outputs aligned with repository rules.",
#       "Follow ordered workflow steps."
#     ],
#     "decisions": [
#       "Use structured five-stage workflow.",
#       "Plan steps: clarify scope, identify affected files, implement changes, review quality, package release",
#       "Kept implementation scoped to plan.",
#       "Review status: approved",
#       "Prepared final release package."
#     ],
#     "artifacts": [
#       "intake_summary",
#       "implementation_plan",
#       "build_output",
#       "review_report",
#       "release_notes"
#     ],
#     "risks": [
#       "Original request may omit hidden assumptions.",
#       "Implementation may drift if the plan is ignored."
#     ],
#     "next_action": "Share final handoff with downstream team.",
#     "notes": {
#       "intake": "Structured request for: Build a document ingestion feature with validation and release notes",
#       "plan": "clarify scope -> identify affected files -> implement changes -> review quality -> package release",
#       "build": "Implemented task 'Build a document ingestion feature with validation and release notes' using plan: clarify scope -> identify affected files -> implement changes -> review quality -> package release",
#       "review": "Artifacts are aligned with plan and ready for release.",
#       "review_status": "approved",
#       "release": "Released task 'Build a document ingestion feature with validation and release notes'. Summary: Implemented task 'Build a document ingestion feature with validation and release notes' using plan: clarify scope -> identify affected files -> implement changes -> review quality -> package release"
#     }
#   }
# }
